# %%
import os
import json
import pickle
import xgboost
from base import ModelHelper

# %load_ext autoreload
# %autoreload 2

# %%
model_helper = ModelHelper("./baseline", "baseline_binary_classifier")

# %%
model_helper
# Out:
# Model Folder = ./baseline
# Metadata Folder = ./baseline/metadata
# Path to data = ./raw-data/full_data.gz
# Path to test data = ./raw-data/test_labelled.gz
# Path to evaluation folder = ./baseline/evaluation
# Seed = 1

# %%
df = model_helper.prepare_data(model_helper.path_to_full_data)
test = model_helper.prepare_data(model_helper.path_to_test_data)

# %%
X_train = df[[col for col in df.columns if col != 'target']]
y_train = df['target']
X_test = test[[col for col in test.columns if col != 'target']]
y_test = test['target']

# %%
xgb_model = xgboost.XGBClassifier(random_state=model_helper.seed)

# %%
best_params = model_helper.random_grid_search(
    X_train, y_train,
    model=xgb_model,
    n_iter=25
)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 30.0min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 30.7min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 52.7min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 54.7min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 70.0min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 70.7min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 71.5min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 72.0min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 72.4min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 160.0min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 160.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 161.6min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 162.2min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 162.3min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 163.1min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 165.4min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 221.8min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 221.9min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 242.5min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 251.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 255.5min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 272.7min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 332.2min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 332.7min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 333.0min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 333.0min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 333.1min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 389.1min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 392.3min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 392.5min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 413.3min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 415.6min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 427.4min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 430.2min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 432.0min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 432.3min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 433.3min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 435.6min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 444.8min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 455.8min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 456.2min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 456.6min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 461.5min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 461.9min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 462.5min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 465.3min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 471.8min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 472.1min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 474.0min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 475.7min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 476.7min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 476.8min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 479.5min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 483.8min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 484.8min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 488.6min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 488.7min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 489.5min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 490.8min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 491.4min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 491.6min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 491.9min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 492.0min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 493.0min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 494.6min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 498.9min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 500.1min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 511.2min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 512.5min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 512.8min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 513.7min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 514.3min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 514.4min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 514.9min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 515.7min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 516.4min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 517.7min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 523.7min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 524.8min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 525.4min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 526.4min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 533.4min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 533.9min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 533.9min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 534.4min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 534.7min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 534.9min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 535.1min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 535.7min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 537.6min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 538.0min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 538.2min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 544.0min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 550.8min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 550.9min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 551.2min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 552.0min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 552.7min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 552.7min
# [Parallel(n_jobs=-1)]: Done 108 out of 125 | elapsed: 559.5min remaining: 88.1min
# [Parallel(n_jobs=-1)]: Done 114 out of 125 | elapsed: 569.9min remaining: 55.0min
# [Parallel(n_jobs=-1)]: Done 120 out of 125 | elapsed: 573.6min remaining: 23.9min
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed: 574.0min finished

# %%
best_params
# Out:
# {'subsample': 0.75,
#  'n_estimators': 75,
#  'max_depth': 4,
#  'learning_rate': 0.3,
#  'gamma': 5}

# %%
xgb_model = xgboost.XGBClassifier(**best_params, random_state=model_helper.seed, early_stopping_rounds=10)
eval_set = [(X_train, y_train), (X_test, y_test)]
xgb_model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
# Out:
# [04:05:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-error:0.00643	validation_1-error:0.07791
# [1]	validation_0-error:0.00657	validation_1-error:0.07806
# [2]	validation_0-error:0.00433	validation_1-error:0.06990
# [3]	validation_0-error:0.00491	validation_1-error:0.07614
# [4]	validation_0-error:0.00238	validation_1-error:0.06162
# [5]	validation_0-error:0.00238	validation_1-error:0.06162
# [6]	validation_0-error:0.00225	validation_1-error:0.06865
# [7]	validation_0-error:0.00227	validation_1-error:0.06552
# [8]	validation_0-error:0.00185	validation_1-error:0.06540
# [9]	validation_0-error:0.00158	validation_1-error:0.06552
# [10]	validation_0-error:0.00147	validation_1-error:0.06535
# [11]	validation_0-error:0.00150	validation_1-error:0.06638
# [12]	validation_0-error:0.00097	validation_1-error:0.06585
# [13]	validation_0-error:0.00102	validation_1-error:0.06560
# [14]	validation_0-error:0.00100	validation_1-error:0.06657
# [15]	validation_0-error:0.00076	validation_1-error:0.06635
# [16]	validation_0-error:0.00065	validation_1-error:0.06765
# [17]	validation_0-error:0.00062	validation_1-error:0.06645
# [18]	validation_0-error:0.00056	validation_1-error:0.06573
# [19]	validation_0-error:0.00055	validation_1-error:0.06354
# [20]	validation_0-error:0.00052	validation_1-error:0.06301
# [21]	validation_0-error:0.00052	validation_1-error:0.06137
# [22]	validation_0-error:0.00052	validation_1-error:0.06124
# [23]	validation_0-error:0.00047	validation_1-error:0.06034
# [24]	validation_0-error:0.00045	validation_1-error:0.06087
# [25]	validation_0-error:0.00046	validation_1-error:0.06129
# [26]	validation_0-error:0.00047	validation_1-error:0.05922
# [27]	validation_0-error:0.00046	validation_1-error:0.05829
# [28]	validation_0-error:0.00044	validation_1-error:0.05804
# [29]	validation_0-error:0.00037	validation_1-error:0.05870
# [30]	validation_0-error:0.00034	validation_1-error:0.05767
# [31]	validation_0-error:0.00033	validation_1-error:0.05804
# [32]	validation_0-error:0.00032	validation_1-error:0.05810
# [33]	validation_0-error:0.00032	validation_1-error:0.05795
# [34]	validation_0-error:0.00031	validation_1-error:0.05871
# [35]	validation_0-error:0.00028	validation_1-error:0.05853
# [36]	validation_0-error:0.00028	validation_1-error:0.05893
# [37]	validation_0-error:0.00027	validation_1-error:0.05743
# [38]	validation_0-error:0.00027	validation_1-error:0.05725
# [39]	validation_0-error:0.00026	validation_1-error:0.05745
# [40]	validation_0-error:0.00026	validation_1-error:0.05728
# [41]	validation_0-error:0.00025	validation_1-error:0.05756
# [42]	validation_0-error:0.00025	validation_1-error:0.05733
# [43]	validation_0-error:0.00023	validation_1-error:0.05737
# [44]	validation_0-error:0.00022	validation_1-error:0.05715
# [45]	validation_0-error:0.00022	validation_1-error:0.05742
# [46]	validation_0-error:0.00022	validation_1-error:0.05722
# [47]	validation_0-error:0.00021	validation_1-error:0.05719
# [48]	validation_0-error:0.00022	validation_1-error:0.05710
# [49]	validation_0-error:0.00022	validation_1-error:0.05715
# [50]	validation_0-error:0.00020	validation_1-error:0.05730
# [51]	validation_0-error:0.00020	validation_1-error:0.05733
# [52]	validation_0-error:0.00020	validation_1-error:0.05748
# [53]	validation_0-error:0.00016	validation_1-error:0.05755
# [54]	validation_0-error:0.00016	validation_1-error:0.05767
# [55]	validation_0-error:0.00015	validation_1-error:0.05765
# [56]	validation_0-error:0.00015	validation_1-error:0.05755
# [57]	validation_0-error:0.00015	validation_1-error:0.05747
# [58]	validation_0-error:0.00015	validation_1-error:0.05739
# [59]	validation_0-error:0.00015	validation_1-error:0.05746
# [60]	validation_0-error:0.00014	validation_1-error:0.05704
# [61]	validation_0-error:0.00014	validation_1-error:0.05736
# [62]	validation_0-error:0.00014	validation_1-error:0.05754
# [63]	validation_0-error:0.00015	validation_1-error:0.05786
# [64]	validation_0-error:0.00015	validation_1-error:0.05781
# [65]	validation_0-error:0.00015	validation_1-error:0.05790
# [66]	validation_0-error:0.00015	validation_1-error:0.05791
# [67]	validation_0-error:0.00014	validation_1-error:0.05788
# [68]	validation_0-error:0.00014	validation_1-error:0.05814
# [69]	validation_0-error:0.00014	validation_1-error:0.05814
# [70]	validation_0-error:0.00013	validation_1-error:0.05809
# [71]	validation_0-error:0.00013	validation_1-error:0.05812
# [72]	validation_0-error:0.00013	validation_1-error:0.05812
# [73]	validation_0-error:0.00013	validation_1-error:0.05817
# [74]	validation_0-error:0.00013	validation_1-error:0.05816
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=10,
#               gamma=5, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.3, max_delta_step=0,
#               max_depth=4, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=75, n_jobs=0,
#               num_parallel_tree=1, random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.75, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
model_helper.model = xgb_model
model_helper.save_model()

# %%
evaluation = model_helper.evaluate_model(X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.92      0.99      0.95     47913
#       attack       0.99      0.86      0.92     29378
#
#     accuracy                           0.94     77291
#    macro avg       0.95      0.93      0.94     77291
# weighted avg       0.95      0.94      0.94     77291

# %%
evaluation
# Out:
# {'accuracy': 0.9418431641458902,
#  'balanced_accuracy': 0.8503916714659043,
#  'prfs': {'precision': {'normal': 0.918349649271564,
#    'attack': 0.9898421197684948},
#   'recall': {'normal': 0.9946152401227224, 'attack': 0.8557764313431819},
#   'f1_score': {'normal': 0.9549621762436752, 'attack': 0.9179400113186191},
#   'support': {'normal': 47913.0, 'attack': 29378.0}},
#  'test_target_proportions': {False: 0.6199039991719605,
#   True: 0.38009600082803946},
#  'model_params': {'objective': 'binary:logistic',
#   'base_score': 0.5,
#   'booster': 'gbtree',
#   'colsample_bylevel': 1,
#   'colsample_bynode': 1,
#   'colsample_bytree': 1,
#   'gamma': 5,
#   'gpu_id': -1,
#   'importance_type': 'gain',
#   'interaction_constraints': '',
#   'learning_rate': 0.3,
#   'max_delta_step': 0,
#   'max_depth': 4,
#   'min_child_weight': 1,
#   'missing': nan,
#   'monotone_constraints': '()',
#   'n_estimators': 75,
#   'n_jobs': 0,
#   'num_parallel_tree': 1,
#   'random_state': 1,
#   'reg_alpha': 0,
#   'reg_lambda': 1,
#   'scale_pos_weight': 1,
#   'subsample': 0.75,
#   'tree_method': 'exact',
#   'validate_parameters': 1,
#   'verbosity': None,
#   'early_stopping_rounds': 10}}
