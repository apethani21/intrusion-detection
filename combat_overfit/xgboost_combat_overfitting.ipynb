# %%
import os
import json
import pickle
import xgboost
from base import ModelHelper

# %load_ext autoreload
# %autoreload 2

# %%
model_helper = ModelHelper("./combat_overfit", "combat_overfit")
model_helper
# Out:
# Model Folder = ./combat_overfit
# Metadata Folder = ./combat_overfit/metadata
# Path to data = ./raw-data/full_data.gz
# Path to test data = ./raw-data/test_labelled.gz
# Path to evaluation folder = ./combat_overfit/evaluation
# Seed = 1

# %%
df = model_helper.prepare_data(model_helper.path_to_full_data)
test = model_helper.prepare_data(model_helper.path_to_test_data)

# %%
X_train = df[[col for col in df.columns if col != 'target']]
y_train = df['target']
X_test = test[[col for col in df.columns if col != 'target']]
y_test = test['target']

# %%
params = {
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "max_depth": 3,
    "early_stopping_rounds": 10,
    "gamma": 10
}

xgb_model = xgboost.XGBClassifier(**params, random_state=model_helper.seed)
eval_set = [(X_train, y_train), (X_test, y_test)]
xgb_model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
model_helper.model = xgb_model
# Out:
# [18:44:36] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-error:0.01063	validation_1-error:0.08707
# [1]	validation_0-error:0.01216	validation_1-error:0.09198
# [2]	validation_0-error:0.00623	validation_1-error:0.07813
# [3]	validation_0-error:0.00554	validation_1-error:0.07640
# [4]	validation_0-error:0.00682	validation_1-error:0.07988
# [5]	validation_0-error:0.00359	validation_1-error:0.07722
# [6]	validation_0-error:0.00379	validation_1-error:0.08048
# [7]	validation_0-error:0.00261	validation_1-error:0.07516
# [8]	validation_0-error:0.00248	validation_1-error:0.07434
# [9]	validation_0-error:0.00249	validation_1-error:0.07988
# [10]	validation_0-error:0.00173	validation_1-error:0.07574
# [11]	validation_0-error:0.00199	validation_1-error:0.07473
# [12]	validation_0-error:0.00195	validation_1-error:0.07728
# [13]	validation_0-error:0.00165	validation_1-error:0.07630
# [14]	validation_0-error:0.00151	validation_1-error:0.07595
# [15]	validation_0-error:0.00164	validation_1-error:0.07685
# [16]	validation_0-error:0.00149	validation_1-error:0.07637
# [17]	validation_0-error:0.00138	validation_1-error:0.07547
# [18]	validation_0-error:0.00142	validation_1-error:0.07529
# [19]	validation_0-error:0.00135	validation_1-error:0.07443
# [20]	validation_0-error:0.00140	validation_1-error:0.07170
# [21]	validation_0-error:0.00108	validation_1-error:0.07339
# [22]	validation_0-error:0.00099	validation_1-error:0.07264
# [23]	validation_0-error:0.00102	validation_1-error:0.07173
# [24]	validation_0-error:0.00088	validation_1-error:0.07036
# [25]	validation_0-error:0.00089	validation_1-error:0.06932
# [26]	validation_0-error:0.00085	validation_1-error:0.06935
# [27]	validation_0-error:0.00070	validation_1-error:0.06936
# [28]	validation_0-error:0.00069	validation_1-error:0.06930
# [29]	validation_0-error:0.00069	validation_1-error:0.06945
# [30]	validation_0-error:0.00067	validation_1-error:0.06747
# [31]	validation_0-error:0.00064	validation_1-error:0.06706
# [32]	validation_0-error:0.00055	validation_1-error:0.06680
# [33]	validation_0-error:0.00055	validation_1-error:0.06869
# [34]	validation_0-error:0.00051	validation_1-error:0.06875
# [35]	validation_0-error:0.00049	validation_1-error:0.06611
# [36]	validation_0-error:0.00046	validation_1-error:0.06494
# [37]	validation_0-error:0.00045	validation_1-error:0.06805
# [38]	validation_0-error:0.00043	validation_1-error:0.06522
# [39]	validation_0-error:0.00041	validation_1-error:0.06469
# [40]	validation_0-error:0.00041	validation_1-error:0.06503
# [41]	validation_0-error:0.00041	validation_1-error:0.06499
# [42]	validation_0-error:0.00040	validation_1-error:0.06505
# [43]	validation_0-error:0.00041	validation_1-error:0.06536
# [44]	validation_0-error:0.00040	validation_1-error:0.06534
# [45]	validation_0-error:0.00040	validation_1-error:0.06547
# [46]	validation_0-error:0.00038	validation_1-error:0.06573
# [47]	validation_0-error:0.00037	validation_1-error:0.06569
# [48]	validation_0-error:0.00037	validation_1-error:0.06567
# [49]	validation_0-error:0.00036	validation_1-error:0.06566
# [50]	validation_0-error:0.00037	validation_1-error:0.06698
# [51]	validation_0-error:0.00035	validation_1-error:0.06749
# [52]	validation_0-error:0.00035	validation_1-error:0.06483
# [53]	validation_0-error:0.00034	validation_1-error:0.06570
# [54]	validation_0-error:0.00033	validation_1-error:0.06688
# [55]	validation_0-error:0.00033	validation_1-error:0.06685
# [56]	validation_0-error:0.00033	validation_1-error:0.06689
# [57]	validation_0-error:0.00033	validation_1-error:0.06714
# [58]	validation_0-error:0.00032	validation_1-error:0.06776
# [59]	validation_0-error:0.00032	validation_1-error:0.06782
# [60]	validation_0-error:0.00031	validation_1-error:0.06724
# [61]	validation_0-error:0.00031	validation_1-error:0.06708
# [62]	validation_0-error:0.00030	validation_1-error:0.06710
# [63]	validation_0-error:0.00029	validation_1-error:0.06723
# [64]	validation_0-error:0.00031	validation_1-error:0.06710
# [65]	validation_0-error:0.00030	validation_1-error:0.06703
# [66]	validation_0-error:0.00028	validation_1-error:0.06714
# [67]	validation_0-error:0.00028	validation_1-error:0.06704
# [68]	validation_0-error:0.00026	validation_1-error:0.06729
# [69]	validation_0-error:0.00026	validation_1-error:0.06728
# [70]	validation_0-error:0.00026	validation_1-error:0.06720
# [71]	validation_0-error:0.00025	validation_1-error:0.06716
# [72]	validation_0-error:0.00025	validation_1-error:0.06720
# [73]	validation_0-error:0.00025	validation_1-error:0.06720
# [74]	validation_0-error:0.00025	validation_1-error:0.06736
# [75]	validation_0-error:0.00025	validation_1-error:0.06712
# [76]	validation_0-error:0.00025	validation_1-error:0.06716
# [77]	validation_0-error:0.00025	validation_1-error:0.06716
# [78]	validation_0-error:0.00025	validation_1-error:0.06743
# [79]	validation_0-error:0.00025	validation_1-error:0.06635
# [80]	validation_0-error:0.00025	validation_1-error:0.06635
# [81]	validation_0-error:0.00025	validation_1-error:0.06626
# [82]	validation_0-error:0.00025	validation_1-error:0.06626
# [83]	validation_0-error:0.00025	validation_1-error:0.06530
# [84]	validation_0-error:0.00025	validation_1-error:0.06545
# [85]	validation_0-error:0.00025	validation_1-error:0.06563
# [86]	validation_0-error:0.00025	validation_1-error:0.06576
# [87]	validation_0-error:0.00024	validation_1-error:0.06617
# [88]	validation_0-error:0.00024	validation_1-error:0.06642
# [89]	validation_0-error:0.00024	validation_1-error:0.06642
# [90]	validation_0-error:0.00024	validation_1-error:0.06604
# [91]	validation_0-error:0.00024	validation_1-error:0.06584
# [92]	validation_0-error:0.00024	validation_1-error:0.06584
# [93]	validation_0-error:0.00023	validation_1-error:0.06513
# [94]	validation_0-error:0.00023	validation_1-error:0.06587
# [95]	validation_0-error:0.00023	validation_1-error:0.06587
# [96]	validation_0-error:0.00023	validation_1-error:0.06589
# [97]	validation_0-error:0.00022	validation_1-error:0.06490
# [98]	validation_0-error:0.00022	validation_1-error:0.06490
# [99]	validation_0-error:0.00023	validation_1-error:0.06500

# %%
print(model_helper.model)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8,
#               early_stopping_rounds=10, gamma=10, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=0.8,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
model_helper.save_model()

# %%
evaluation = model_helper.evaluate_model(X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.91      0.99      0.95     47913
#       attack       0.99      0.84      0.91     29378
#
#     accuracy                           0.93     77291
#    macro avg       0.95      0.92      0.93     77291
# weighted avg       0.94      0.93      0.93     77291

# %%
evaluation
# Out:
# {'accuracy': 0.9349989002600562,
#  'balanced_accuracy': 0.8325035110377468,
#  'prfs': {'precision': {'normal': 0.9092227544224567,
#    'attack': 0.9892719382835101},
#   'recall': {'normal': 0.9944273996618872, 'attack': 0.8380761113758595},
#   'f1_score': {'normal': 0.9499182583037601, 'attack': 0.9074190100615487},
#   'support': {'normal': 47913.0, 'attack': 29378.0}},
#  'test_target_proportions': {False: 0.6199039991719605,
#   True: 0.38009600082803946},
#  'model_params': {'objective': 'binary:logistic',
#   'base_score': 0.5,
#   'booster': 'gbtree',
#   'colsample_bylevel': 1,
#   'colsample_bynode': 1,
#   'colsample_bytree': 0.8,
#   'gamma': 10,
#   'gpu_id': -1,
#   'importance_type': 'gain',
#   'interaction_constraints': '',
#   'learning_rate': 0.300000012,
#   'max_delta_step': 0,
#   'max_depth': 3,
#   'min_child_weight': 1,
#   'missing': nan,
#   'monotone_constraints': '()',
#   'n_estimators': 100,
#   'n_jobs': 0,
#   'num_parallel_tree': 1,
#   'random_state': 1,
#   'reg_alpha': 0,
#   'reg_lambda': 1,
#   'scale_pos_weight': 1,
#   'subsample': 0.8,
#   'tree_method': 'exact',
#   'validate_parameters': 1,
#   'verbosity': None,
#   'early_stopping_rounds': 10}}
