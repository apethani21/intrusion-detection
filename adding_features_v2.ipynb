# %%
import os
import json
import pickle
import xgboost
import numpy as np
import seaborn as sns
from base import ModelHelper

# %load_ext autoreload
# %autoreload 2

# %%
model_helper = ModelHelper("./adding_features_v2", "adding_features_v2")

# %%
model_helper
# Out:
# Model Folder = ./adding_features_v2
# Metadata Folder = ./adding_features_v2/metadata
# Path to data = ./raw-data/full_data.gz
# Path to test data = ./raw-data/test_labelled.gz
# Path to evaluation folder = ./adding_features_v2/evaluation
# Seed = 1

# %%
df = model_helper.prepare_data(model_helper.path_to_full_data)
test = model_helper.prepare_data(model_helper.path_to_test_data)
# Out:
# service_encoding.pkl missing. creating now.

# %%
df["feature1"] = np.log(df["src_bytes"] + df["dst_bytes"] + 1)
df["feature2"] = np.log(df['src_bytes']*df['dst_bytes']+1)
df["feature3"] = df["same_srv_rate"] + df["diff_srv_rate"]
df["feature4"] = df["same_srv_rate"]*df["diff_srv_rate"]
df["feature5"] = df["dst_host_same_srv_rate"] + df["dst_host_diff_srv_rate"]
df["feature6"] = df["dst_host_same_srv_rate"]*df["dst_host_diff_srv_rate"]
df["feature7"] = np.log(df['duration']+1)
df["feature8"] = np.log(df['num_root']/(df["duration"] + 1) + 1)

test["feature1"] = np.log(test["src_bytes"] + test["dst_bytes"] + 1)
test["feature2"] = np.log(test['src_bytes']*test['dst_bytes']+1)
test["feature3"] = test["same_srv_rate"] + test["diff_srv_rate"]
test["feature4"] = test["same_srv_rate"]*test["diff_srv_rate"]
test["feature5"] = test["dst_host_same_srv_rate"] + test["dst_host_diff_srv_rate"]
test["feature6"] = test["dst_host_same_srv_rate"]*test["dst_host_diff_srv_rate"]
test["feature7"] = np.log(test['duration']+1)
test["feature8"] = np.log(test['num_root']/(df["duration"] + 1) + 1)

# %%
best_weight_features = ["src_bytes", "service", "dst_bytes", "dst_host_srv_count", "dst_host_count",
                        "dst_host_rerror_rate", "dst_host_same_srv_rate", "dst_host_same_src_port_rate",
                        "duration", "dst_host_srv_diff_host_rate"]
best_gain_features = ["same_srv_rate", "flag_RSTR", "prototype_icmp", "wrong_fragment", "srv_serror_rate",
                      "dst_host_srv_serror_rate", "srv_count", "dst_host_serror_rate", "num_compromised",
                      "src_bytes"]
best_cover_features = ["flag_RSTR", "wrong_fragment", "num_failed_logins", "same_srv_rate", "srv_serror_rate",
                       "urgent", "prototype_icmp", "num_compromised", "hot", "diff_srv_rate"]


features_to_keep = {*best_weight_features, *best_gain_features, *best_cover_features,
                    *[col for col in df.columns if "feature" in col]}
print(len(features_to_keep))
# Out:
# 31

# %%
df = df[[col for col in df.columns if col in features_to_keep or col == "target"]]
test = test[[col for col in test.columns if col in features_to_keep or col == "target"]]

# %%
X_train = df[[col for col in df.columns if col != 'target']]
y_train = df['target']
X_test = test[[col for col in test.columns if col != 'target']]
y_test = test['target']

# %%
xgb_model = xgboost.XGBClassifier(random_state=model_helper.seed)

# %%
best_params = model_helper.random_grid_search(
    X_train, y_train,
    model=xgb_model,
    n_iter=25
)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 18.2min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 24.2min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 24.6min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 25.6min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 26.2min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 108 out of 125 | elapsed: 27.2min remaining:  4.3min
# [Parallel(n_jobs=-1)]: Done 114 out of 125 | elapsed: 29.7min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done 120 out of 125 | elapsed: 31.2min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed: 31.4min finished

# %%
best_params
# Out:
# {'subsample': 0.75,
#  'n_estimators': 75,
#  'max_depth': 6,
#  'learning_rate': 0.5,
#  'gamma': 2.5}

# %%
xgb_model = xgboost.XGBClassifier(**best_params, random_state=model_helper.seed, early_stopping_rounds=10)
eval_set = [(X_train, y_train), (X_test, y_test)]
xgb_model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
# Out:
# [00:25:47] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-error:0.00251	validation_1-error:0.08009
# [1]	validation_0-error:0.00236	validation_1-error:0.07903
# [2]	validation_0-error:0.00102	validation_1-error:0.06703
# [3]	validation_0-error:0.00124	validation_1-error:0.06949
# [4]	validation_0-error:0.00058	validation_1-error:0.06716
# [5]	validation_0-error:0.00052	validation_1-error:0.06704
# [6]	validation_0-error:0.00045	validation_1-error:0.06733
# [7]	validation_0-error:0.00041	validation_1-error:0.07210
# [8]	validation_0-error:0.00040	validation_1-error:0.07207
# [9]	validation_0-error:0.00032	validation_1-error:0.06730
# [10]	validation_0-error:0.00030	validation_1-error:0.07046
# [11]	validation_0-error:0.00031	validation_1-error:0.06799
# [12]	validation_0-error:0.00023	validation_1-error:0.06734
# [13]	validation_0-error:0.00018	validation_1-error:0.06682
# [14]	validation_0-error:0.00017	validation_1-error:0.06615
# [15]	validation_0-error:0.00016	validation_1-error:0.06615
# [16]	validation_0-error:0.00016	validation_1-error:0.06443
# [17]	validation_0-error:0.00015	validation_1-error:0.06560
# [18]	validation_0-error:0.00015	validation_1-error:0.06457
# [19]	validation_0-error:0.00013	validation_1-error:0.06441
# [20]	validation_0-error:0.00012	validation_1-error:0.06595
# [21]	validation_0-error:0.00011	validation_1-error:0.06431
# [22]	validation_0-error:0.00011	validation_1-error:0.06441
# [23]	validation_0-error:0.00010	validation_1-error:0.06536
# [24]	validation_0-error:0.00010	validation_1-error:0.06507
# [25]	validation_0-error:0.00010	validation_1-error:0.06437
# [26]	validation_0-error:0.00009	validation_1-error:0.06490
# [27]	validation_0-error:0.00009	validation_1-error:0.06450
# [28]	validation_0-error:0.00009	validation_1-error:0.06441
# [29]	validation_0-error:0.00008	validation_1-error:0.06438
# [30]	validation_0-error:0.00008	validation_1-error:0.06368
# [31]	validation_0-error:0.00008	validation_1-error:0.06416
# [32]	validation_0-error:0.00007	validation_1-error:0.06463
# [33]	validation_0-error:0.00007	validation_1-error:0.06358
# [34]	validation_0-error:0.00007	validation_1-error:0.06397
# [35]	validation_0-error:0.00006	validation_1-error:0.06411
# [36]	validation_0-error:0.00006	validation_1-error:0.06443
# [37]	validation_0-error:0.00006	validation_1-error:0.06446
# [38]	validation_0-error:0.00006	validation_1-error:0.06447
# [39]	validation_0-error:0.00006	validation_1-error:0.06527
# [40]	validation_0-error:0.00006	validation_1-error:0.06525
# [41]	validation_0-error:0.00005	validation_1-error:0.06460
# [42]	validation_0-error:0.00005	validation_1-error:0.06451
# [43]	validation_0-error:0.00005	validation_1-error:0.06494
# [44]	validation_0-error:0.00005	validation_1-error:0.06433
# [45]	validation_0-error:0.00005	validation_1-error:0.06439
# [46]	validation_0-error:0.00005	validation_1-error:0.06456
# [47]	validation_0-error:0.00005	validation_1-error:0.06435
# [48]	validation_0-error:0.00005	validation_1-error:0.06433
# [49]	validation_0-error:0.00004	validation_1-error:0.06382
# [50]	validation_0-error:0.00004	validation_1-error:0.06366
# [51]	validation_0-error:0.00004	validation_1-error:0.06366
# [52]	validation_0-error:0.00004	validation_1-error:0.06360
# [53]	validation_0-error:0.00004	validation_1-error:0.06367
# [54]	validation_0-error:0.00005	validation_1-error:0.06380
# [55]	validation_0-error:0.00005	validation_1-error:0.06388
# [56]	validation_0-error:0.00004	validation_1-error:0.06388
# [57]	validation_0-error:0.00004	validation_1-error:0.06388
# [58]	validation_0-error:0.00004	validation_1-error:0.06391
# [59]	validation_0-error:0.00004	validation_1-error:0.06391
# [60]	validation_0-error:0.00004	validation_1-error:0.06351
# [61]	validation_0-error:0.00004	validation_1-error:0.06350
# [62]	validation_0-error:0.00004	validation_1-error:0.06346
# [63]	validation_0-error:0.00004	validation_1-error:0.06347
# [64]	validation_0-error:0.00004	validation_1-error:0.06347
# [65]	validation_0-error:0.00004	validation_1-error:0.06345
# [66]	validation_0-error:0.00004	validation_1-error:0.06334
# [67]	validation_0-error:0.00004	validation_1-error:0.06337
# [68]	validation_0-error:0.00004	validation_1-error:0.06337
# [69]	validation_0-error:0.00004	validation_1-error:0.06245
# [70]	validation_0-error:0.00004	validation_1-error:0.06243
# [71]	validation_0-error:0.00004	validation_1-error:0.06244
# [72]	validation_0-error:0.00004	validation_1-error:0.06267
# [73]	validation_0-error:0.00004	validation_1-error:0.06144
# [74]	validation_0-error:0.00004	validation_1-error:0.06147
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=10,
#               gamma=2.5, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.5, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=75, n_jobs=0,
#               num_parallel_tree=1, random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.75, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
model_helper.model = xgb_model
model_helper.save_model()

# %%
evaluation = model_helper.evaluate_model(X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.91      0.99      0.95     47913
#       attack       0.99      0.85      0.91     29378
#
#     accuracy                           0.94     77291
#    macro avg       0.95      0.92      0.93     77291
# weighted avg       0.94      0.94      0.94     77291

# %%
evaluation
# Out:
# {'accuracy': 0.9385310061973581,
#  'balanced_accuracy': 0.8418225148496814,
#  'prfs': {'precision': {'normal': 0.9140160380616199,
#    'attack': 0.989310550367574},
#   'recall': {'normal': 0.9943856573372571, 'attack': 0.8474368575124243},
#   'f1_score': {'normal': 0.9525085216765461, 'attack': 0.9128944135819446},
#   'support': {'normal': 47913.0, 'attack': 29378.0}},
#  'test_target_proportions': {False: 0.6199039991719605,
#   True: 0.38009600082803946},
#  'model_params': {'objective': 'binary:logistic',
#   'base_score': 0.5,
#   'booster': 'gbtree',
#   'colsample_bylevel': 1,
#   'colsample_bynode': 1,
#   'colsample_bytree': 1,
#   'gamma': 2.5,
#   'gpu_id': -1,
#   'importance_type': 'gain',
#   'interaction_constraints': '',
#   'learning_rate': 0.5,
#   'max_delta_step': 0,
#   'max_depth': 6,
#   'min_child_weight': 1,
#   'missing': nan,
#   'monotone_constraints': '()',
#   'n_estimators': 75,
#   'n_jobs': 0,
#   'num_parallel_tree': 1,
#   'random_state': 1,
#   'reg_alpha': 0,
#   'reg_lambda': 1,
#   'scale_pos_weight': 1,
#   'subsample': 0.75,
#   'tree_method': 'exact',
#   'validate_parameters': 1,
#   'verbosity': None,
#   'early_stopping_rounds': 10}}
