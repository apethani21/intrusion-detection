# %%
import os
import json
import pickle
import xgboost
import numpy as np
import seaborn as sns
from base import ModelHelper

# %load_ext autoreload
# %autoreload 2

# %%
model_helper = ModelHelper("./adding_features_v3", "adding_features_v3")

# %%
model_helper
# Out:
# Model Folder = ./adding_features_v3
# Metadata Folder = ./adding_features_v3/metadata
# Path to data = ./raw-data/full_data.gz
# Path to test data = ./raw-data/test_labelled.gz
# Path to evaluation folder = ./adding_features_v3/evaluation
# Seed = 1

# %%
df = model_helper.prepare_data(model_helper.path_to_full_data)
test = model_helper.prepare_data(model_helper.path_to_test_data)
# Out:
# service_encoding.pkl missing. creating now.

# %%
df["feature1"] = np.log(df["src_bytes"] + df["dst_bytes"] + 1)
df["feature2"] = np.log(df['src_bytes']*df['dst_bytes']+1)
df["feature3"] = df["same_srv_rate"] + df["diff_srv_rate"]
df["feature4"] = df["same_srv_rate"]*df["diff_srv_rate"]
df["feature5"] = df["dst_host_same_srv_rate"] + df["dst_host_diff_srv_rate"]
df["feature6"] = df["dst_host_same_srv_rate"]*df["dst_host_diff_srv_rate"]
df["feature7"] = np.log(df['duration']+1)
df["feature8"] = np.log(df['num_root']/(df["duration"] + 1) + 1)

test["feature1"] = np.log(test["src_bytes"] + test["dst_bytes"] + 1)
test["feature2"] = np.log(test['src_bytes']*test['dst_bytes']+1)
test["feature3"] = test["same_srv_rate"] + test["diff_srv_rate"]
test["feature4"] = test["same_srv_rate"]*test["diff_srv_rate"]
test["feature5"] = test["dst_host_same_srv_rate"] + test["dst_host_diff_srv_rate"]
test["feature6"] = test["dst_host_same_srv_rate"]*test["dst_host_diff_srv_rate"]
test["feature7"] = np.log(test['duration']+1)
test["feature8"] = np.log(test['num_root']/(df["duration"] + 1) + 1)

# %%
best_weight_features = ["src_bytes", "service", "dst_bytes", "dst_host_srv_count", "dst_host_count"]
best_gain_features = ["same_srv_rate", "flag_RSTR", "prototype_icmp", "wrong_fragment", "srv_serror_rate"]
best_cover_features = ["flag_RSTR", "wrong_fragment", "num_failed_logins", "same_srv_rate", "srv_serror_rate"]


features_to_keep = {*best_weight_features, *best_gain_features, *best_cover_features,
                    *[col for col in df.columns if "feature" in col]}
print(len(features_to_keep))
# Out:
# 19

# %%
df = df[[col for col in df.columns if col in features_to_keep or col == "target"]]
test = test[[col for col in test.columns if col in features_to_keep or col == "target"]]

# %%
X_train = df[[col for col in df.columns if col != 'target']]
y_train = df['target']
X_test = test[[col for col in test.columns if col != 'target']]
y_test = test['target']

# %%
xgb_model = xgboost.XGBClassifier(random_state=model_helper.seed)

# %%
best_params = model_helper.random_grid_search(
    X_train, y_train,
    model=xgb_model,
    n_iter=25
)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 15.0min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done 108 out of 125 | elapsed: 18.3min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done 114 out of 125 | elapsed: 20.0min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done 120 out of 125 | elapsed: 21.0min remaining:   52.5s
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed: 21.2min finished

# %%
best_params
# Out:
# {'subsample': 0.75,
#  'n_estimators': 100,
#  'max_depth': 6,
#  'learning_rate': 0.5,
#  'gamma': 5}

# %%
xgb_model = xgboost.XGBClassifier(**best_params, random_state=model_helper.seed, early_stopping_rounds=10)
eval_set = [(X_train, y_train), (X_test, y_test)]
xgb_model.fit(X_train, y_train, eval_set=eval_set, verbose=True)
# Out:
# [00:54:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-error:0.00296	validation_1-error:0.07381
# [1]	validation_0-error:0.00278	validation_1-error:0.07370
# [2]	validation_0-error:0.00226	validation_1-error:0.06954
# [3]	validation_0-error:0.00158	validation_1-error:0.06870
# [4]	validation_0-error:0.00099	validation_1-error:0.06696
# [5]	validation_0-error:0.00097	validation_1-error:0.06245
# [6]	validation_0-error:0.00077	validation_1-error:0.06150
# [7]	validation_0-error:0.00065	validation_1-error:0.06419
# [8]	validation_0-error:0.00062	validation_1-error:0.06175
# [9]	validation_0-error:0.00042	validation_1-error:0.06692
# [10]	validation_0-error:0.00032	validation_1-error:0.06360
# [11]	validation_0-error:0.00028	validation_1-error:0.06032
# [12]	validation_0-error:0.00027	validation_1-error:0.06182
# [13]	validation_0-error:0.00026	validation_1-error:0.06504
# [14]	validation_0-error:0.00025	validation_1-error:0.06240
# [15]	validation_0-error:0.00023	validation_1-error:0.06862
# [16]	validation_0-error:0.00023	validation_1-error:0.06917
# [17]	validation_0-error:0.00022	validation_1-error:0.06655
# [18]	validation_0-error:0.00021	validation_1-error:0.06423
# [19]	validation_0-error:0.00020	validation_1-error:0.06542
# [20]	validation_0-error:0.00019	validation_1-error:0.06426
# [21]	validation_0-error:0.00018	validation_1-error:0.06430
# [22]	validation_0-error:0.00018	validation_1-error:0.06457
# [23]	validation_0-error:0.00018	validation_1-error:0.06431
# [24]	validation_0-error:0.00018	validation_1-error:0.06415
# [25]	validation_0-error:0.00018	validation_1-error:0.06389
# [26]	validation_0-error:0.00017	validation_1-error:0.06347
# [27]	validation_0-error:0.00015	validation_1-error:0.06353
# [28]	validation_0-error:0.00015	validation_1-error:0.06333
# [29]	validation_0-error:0.00015	validation_1-error:0.06313
# [30]	validation_0-error:0.00014	validation_1-error:0.06424
# [31]	validation_0-error:0.00013	validation_1-error:0.06474
# [32]	validation_0-error:0.00013	validation_1-error:0.06467
# [33]	validation_0-error:0.00013	validation_1-error:0.06483
# [34]	validation_0-error:0.00014	validation_1-error:0.06443
# [35]	validation_0-error:0.00014	validation_1-error:0.06441
# [36]	validation_0-error:0.00014	validation_1-error:0.06465
# [37]	validation_0-error:0.00014	validation_1-error:0.06445
# [38]	validation_0-error:0.00013	validation_1-error:0.06448
# [39]	validation_0-error:0.00013	validation_1-error:0.06448
# [40]	validation_0-error:0.00012	validation_1-error:0.06460
# [41]	validation_0-error:0.00012	validation_1-error:0.06428
# [42]	validation_0-error:0.00012	validation_1-error:0.06428
# [43]	validation_0-error:0.00012	validation_1-error:0.06429
# [44]	validation_0-error:0.00013	validation_1-error:0.06368
# [45]	validation_0-error:0.00013	validation_1-error:0.06430
# [46]	validation_0-error:0.00013	validation_1-error:0.06430
# [47]	validation_0-error:0.00012	validation_1-error:0.06459
# [48]	validation_0-error:0.00012	validation_1-error:0.06495
# [49]	validation_0-error:0.00012	validation_1-error:0.06496
# [50]	validation_0-error:0.00012	validation_1-error:0.06486
# [51]	validation_0-error:0.00012	validation_1-error:0.06483
# [52]	validation_0-error:0.00012	validation_1-error:0.06491
# [53]	validation_0-error:0.00012	validation_1-error:0.06491
# [54]	validation_0-error:0.00012	validation_1-error:0.06494
# [55]	validation_0-error:0.00012	validation_1-error:0.06521
# [56]	validation_0-error:0.00011	validation_1-error:0.06334
# [57]	validation_0-error:0.00011	validation_1-error:0.06333
# [58]	validation_0-error:0.00011	validation_1-error:0.06334
# [59]	validation_0-error:0.00011	validation_1-error:0.06333
# [60]	validation_0-error:0.00011	validation_1-error:0.06333
# [61]	validation_0-error:0.00011	validation_1-error:0.06333
# [62]	validation_0-error:0.00011	validation_1-error:0.06334
# [63]	validation_0-error:0.00011	validation_1-error:0.06336
# [64]	validation_0-error:0.00012	validation_1-error:0.06356
# [65]	validation_0-error:0.00012	validation_1-error:0.06355
# [66]	validation_0-error:0.00012	validation_1-error:0.06347
# [67]	validation_0-error:0.00012	validation_1-error:0.06349
# [68]	validation_0-error:0.00011	validation_1-error:0.06358
# [69]	validation_0-error:0.00011	validation_1-error:0.06367
# [70]	validation_0-error:0.00011	validation_1-error:0.06364
# [71]	validation_0-error:0.00011	validation_1-error:0.06364
# [72]	validation_0-error:0.00011	validation_1-error:0.06359
# [73]	validation_0-error:0.00011	validation_1-error:0.06355
# [74]	validation_0-error:0.00011	validation_1-error:0.06356
# [75]	validation_0-error:0.00010	validation_1-error:0.06364
# [76]	validation_0-error:0.00010	validation_1-error:0.06364
# [77]	validation_0-error:0.00010	validation_1-error:0.06364
# [78]	validation_0-error:0.00011	validation_1-error:0.06356
# [79]	validation_0-error:0.00011	validation_1-error:0.06356
# [80]	validation_0-error:0.00011	validation_1-error:0.06358
# [81]	validation_0-error:0.00011	validation_1-error:0.06358
# [82]	validation_0-error:0.00010	validation_1-error:0.06368
# [83]	validation_0-error:0.00010	validation_1-error:0.06368
# [84]	validation_0-error:0.00011	validation_1-error:0.06360
# [85]	validation_0-error:0.00010	validation_1-error:0.06368
# [86]	validation_0-error:0.00010	validation_1-error:0.06369
# [87]	validation_0-error:0.00010	validation_1-error:0.06371
# [88]	validation_0-error:0.00010	validation_1-error:0.06369
# [89]	validation_0-error:0.00010	validation_1-error:0.06368
# [90]	validation_0-error:0.00010	validation_1-error:0.06369
# [91]	validation_0-error:0.00010	validation_1-error:0.06368
# [92]	validation_0-error:0.00010	validation_1-error:0.06380
# [93]	validation_0-error:0.00010	validation_1-error:0.06380
# [94]	validation_0-error:0.00010	validation_1-error:0.06381
# [95]	validation_0-error:0.00010	validation_1-error:0.06381
# [96]	validation_0-error:0.00010	validation_1-error:0.06380
# [97]	validation_0-error:0.00010	validation_1-error:0.06378
# [98]	validation_0-error:0.00010	validation_1-error:0.06378
# [99]	validation_0-error:0.00010	validation_1-error:0.06380
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=10,
#               gamma=5, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.5, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, random_state=1, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=0.75, tree_method='exact',
#               validate_parameters=1, verbosity=None)

# %%
model_helper.model = xgb_model
model_helper.save_model()

# %%
evaluation = model_helper.evaluate_model(X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#       normal       0.91      0.99      0.95     47913
#       attack       0.99      0.84      0.91     29378
#
#     accuracy                           0.94     77291
#    macro avg       0.95      0.92      0.93     77291
# weighted avg       0.94      0.94      0.94     77291

# %%
evaluation
# Out:
# {'accuracy': 0.9362021451397964,
#  'balanced_accuracy': 0.8360773505366499,
#  'prfs': {'precision': {'normal': 0.9113267493492574,
#    'attack': 0.9881004671964222},
#   'recall': {'normal': 0.9937803936301213, 'attack': 0.8422969569065287},
#   'f1_score': {'normal': 0.9507692614890026, 'attack': 0.9093915951562815},
#   'support': {'normal': 47913.0, 'attack': 29378.0}},
#  'test_target_proportions': {False: 0.6199039991719605,
#   True: 0.38009600082803946},
#  'model_params': {'objective': 'binary:logistic',
#   'base_score': 0.5,
#   'booster': 'gbtree',
#   'colsample_bylevel': 1,
#   'colsample_bynode': 1,
#   'colsample_bytree': 1,
#   'gamma': 5,
#   'gpu_id': -1,
#   'importance_type': 'gain',
#   'interaction_constraints': '',
#   'learning_rate': 0.5,
#   'max_delta_step': 0,
#   'max_depth': 6,
#   'min_child_weight': 1,
#   'missing': nan,
#   'monotone_constraints': '()',
#   'n_estimators': 100,
#   'n_jobs': 0,
#   'num_parallel_tree': 1,
#   'random_state': 1,
#   'reg_alpha': 0,
#   'reg_lambda': 1,
#   'scale_pos_weight': 1,
#   'subsample': 0.75,
#   'tree_method': 'exact',
#   'validate_parameters': 1,
#   'verbosity': None,
#   'early_stopping_rounds': 10}}
